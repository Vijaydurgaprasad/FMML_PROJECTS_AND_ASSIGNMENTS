# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaydurgaprasad/FMML_PROJECTS_AND_ASSIGNMENTS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-08 11:59:09--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  90.0MB/s    in 0.8s
#
# 2024-04-08 11:59:12 (90.0 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 23717   1104.2069v1  The main goal of the GEOMIR2K9 project is to c...    cs
# 1878   1802.04223v1  Structured prediction requires searching over ...  stat
# 22513  1610.06235v1  Independent component analysis (ICA) is a powe...  stat
# 7470   1801.02257v1  We propose denoising dictionary learning (DDL)...  stat
# 3404   1611.09958v2  In order to study the application of artificia...  stat
# ...             ...                                                ...   ...
# 24100  1612.05601v2  Identifying and interpreting fetal standard sc...    cs
# 21584   1105.2493v6  We define and discuss the first sparse coding ...  stat
# 6278   1610.08628v1  We consider the problem of transfer learning i...  stat
# 22866  1709.05552v1  We consider a graphical model where a multivar...  stat
# 22396  1605.07596v3  We extend the traditional worst-case, minimax ...  stat
#
#                                                    title  year  \
# 23717                 GEOMIR2K9 - A Similar Scene Finder  2011
# 1878   SparseMAP: Differentiable Sparse Structured In...  2018
# 22513  Enhancing ICA Performance by Exploiting Sparsi...  2016
# 7470   Denoising Dictionary Learning Against Adversar...  2018
# 3404          Machine Learning for Dental Image Analysis  2016
# ...                                                  ...   ...
# 24100  SonoNet: Real-Time Detection and Localisation ...  2016
# 21584  Closed-form EM for Sparse Coding and its Appli...  2011
# 6278                 Regret Bounds for Lifelong Learning  2016
# 22866   Multivariate Gaussian Network Structure Learning  2017
# 22396  Local Minimax Complexity of Stochastic Convex ...  2016
#
#                                                 keywords
# 23717  [clustered, geographical, similarity, meaningf...
# 1878   [structured, prediction, searching, combinator...
# 22513  [independent, component, separation, assumptio...
# 7470   [denoising, dictionary, effective, technique, ...
# 3404   [application, artificial, intelligence, techno...
# ...                                                  ...
# 24100  [identifying, interpreting, ultrasound, pregna...
# 21584  [algorithm, continuous, variables, underlying,...
# 6278   [different, presented, sequentially, processed...
# 22866  [graphical, multivariate, associated, underlyi...
# 22396  [traditional, stochastic, optimization, introd...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 23717    [clustered, geographical, similarity, meaningf...
# 1878     [structured, prediction, searching, combinator...
# 22513    [independent, component, separation, assumptio...
# 7470     [denoising, dictionary, effective, technique, ...
# 3404     [application, artificial, intelligence, techno...
#                                ...
# 30984    [efficient, information, appearance, recogniti...
# 25270    [frequently, compressed, sequences, especially...
# 2170     [regression, regression, surrogate, evolutiona...
# 36665    [architecture, specifying, interaction, charac...
# 22733    [identifying, homogeneous, heterogeneous, impo...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8804 words.
# Out of those 4539 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="741fbdd3-9e70-40a7-a2ea-48dcd1dc85d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("741fbdd3-9e70-40a7-a2ea-48dcd1dc85d9")) {                    Plotly.newPlot(                        "741fbdd3-9e70-40a7-a2ea-48dcd1dc85d9",                        [{"x":["technically","clustered","classification","extraction","interface","geographical","information","retrieved","visualization","similarity","meaningful","retrieval","processing","clustering","efficient","inference","automatically","including","functions","searching","structured","importantly","applicable","intractable","probability","competitive","introduce","ambiguities","prediction","structures","dependency","implausible","regardless","assignment","attractive","structure","differentiable","experiments","corresponding","combinatorial","backpropagation","interpretability","parameter","synthetic","independent","separation","exploitation","algorithm","assumption","application","performance","minimization","restrictive","additionally","incorporated","component","diversity","applications","statistically","enhancing","independence","statistical","important","improvement","available","resulting","resonance","exploiting","functional","simulations","perturbed","perturbations","dictionary","indicating","evaluated","representing","reconstruction","protection","complexity","misclassified","architectures","effective","confidence","adversarial","architecture","previously","progression","technique","successive","techniques","representations","perturbation","denoising","different","implement","panoramic","transform","gradients","representative","artificial","histogram","invariant","convolutional","algorithms","cognition","radiographs","intelligence","technology","unscented","traditional","derivation","parameters","management","complicated","nonlinear","attention","perception","described","environment","potential","estimation","mechanism","calculations","comparison","cognitive","evaluation","simulation","computation","computing","implemented","technical","presumably","programming","probabilistic","describes","deconvolution","iterations","literature","variables","theoretical","dimensional","mentioned","procedure","community","validated","counterpart","silhouettes","boltzmann","observations","surprising","regarding","efficiency","distributed","expectation","representational","demonstrate","inefficient","binarized","generative","alternative","approximate","efficiently","advantages","representation","outperform","restricted","empirical","evidences","generation","captioning","decomposition","computational","challenging","convergence","recognition","outperforms","expensive","approximations","specifically","recurrent","approximation","predicting","correlation","transactions","regression","predictions","therefore","correlations","adjacency","operators","overcomes","heterogeneous","respectively","transportation","examination","schedules","generalization","supervised","dimension","implementation"],"y":[2,8,488,117,21,7,704,16,24,147,56,103,265,136,416,220,188,263,210,33,123,32,62,23,170,109,326,8,234,142,47,1,12,28,20,341,23,637,140,37,17,16,131,152,128,22,15,810,69,241,866,58,5,62,31,88,47,421,30,16,33,158,350,141,324,154,21,74,47,47,3,21,61,14,138,59,81,10,208,3,110,260,45,102,249,107,7,250,10,365,228,10,31,731,58,4,73,37,36,147,24,74,361,595,15,0,92,50,2,173,17,241,51,31,61,162,47,70,111,175,205,122,10,129,44,251,80,140,114,116,37,2,127,168,80,2,24,136,121,144,168,21,121,74,29,17,4,19,92,16,34,173,96,37,8,573,10,3,137,99,106,175,80,380,93,54,143,6,145,16,63,281,262,111,368,257,66,37,176,161,114,83,83,1,110,87,138,24,6,37,9,36,95,8,5,6,103,210,62,123],"type":"bar"},{"x":["technically","cluster ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4539,), (4539, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bayesian</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Completion</span> <span style=''>via</span> <span style=''>Adaptive</span> <span style=''>Relaxed</span> <span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>Regularization</span> <br/><br/><span style=''>Bayesian</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>has</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.4137931034482758);'>factorization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.34104046242774566);'>promising</span> <span style=''>results</span> <span style=''>However</span> <span style=''>little</span> <span style=''>work</span> <span style=''>has</span> <span style=''>been</span> <span style=''>done</span> <span style=''>on</span> <span style=''>Bayesian</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>more</span> <span style=''>direct</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>We</span> <span style=''>fill</span> <span style=''>this</span> <span style=''>gap</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>presenting</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>Bayesian</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>regularization</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>circumvent</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulties</span> <span style=''>of</span> <span style=''>dealing</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>orthonormality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>of</span> <span style=''>singular</span> <span style=''>vectors</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalent</span> <span style=''>form</span> <span style=''>with</span> <span style=''>relaxed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>which</span> <span style=''>then</span> <span style=''>leads</span> <span style=''>us</span> <span style=''>to</span> <span style=''>design</span> <span style=''>an</span> <span style=''>adaptive</span> <span style=''>version</span> <span style=''>of</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>regularization</span> <span style=''>feasible</span> <span style=''>for</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>Our</span> <span style=''>Bayesian</span> <span style=''>method</span> <span style=''>requires</span> <span style=''>no</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>tuning</span> <span style=''>and</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Posterior</span> <span style=''>and</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>on</span> <span style=''>Streams</span> <br/><br/><span style=''>Many</span> <span style=''>modern</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>problems</span> <span style=''>involve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferences</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style=''>data</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>streaming</span> <span style=''>data</span> <span style=''>is</span> <span style=''>not</span> <span style=''>easily</span> <span style=''>amenable</span> <span style=''>to</span> <span style=''>the</span> <span style=''>standard</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>modeling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>which</span> <span style=''>assume</span> <span style=''>that</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>condition</span> <span style=''>on</span> <span style=''>finite</span> <span style=''>data</span> <span style=''>We</span> <span style=''>develop</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style=''>Bayes</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>using</span> <span style=''>Bayesian</span> <span style=''>modeling</span> <span style=''>to</span> <span style=''>analyze</span> <span style=''>streams</span> <span style=''>of</span> <span style=''>data</span> <span style=''>It</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>a</span> <span style=''>new</span> <span style=''>type</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=''>which</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>notion</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>population</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>with</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>We</span> <span style=''>study</span> <span style=''>our</span> <span style=''>method</span> <span style=''>with</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>allocation</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dirichlet</span> <span style=''>process</span> <span style=''>mixtures</span> <span style=''>on</span> <span style=''>several</span> <span style=''>large</span> <span style=''>scale</span> <span style=''>data</span> <span style=''>sets</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Probabilistic</span> <span style=''>Feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <span style=''>Vector</span> <span style=''>Machine</span> <br/><br/><span style=''>Sparse</span> <span style=''>Bayesian</span> <span style=''>learning</span> <span style=''>is</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>which</span> <span style=''>is</span> <span style=''>able</span> <span style=''>to</span> <span style=''>make</span> <span style=''>stable</span> <span style=''>and</span> <span style=''>reliable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictions</span> <span style=''>However</span> <span style=''>some</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>eg</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>vector</span> <span style=''>machine</span> <span style=''>(PCVM)</span> <span style=''>and</span> <span style=''>relevant</span> <span style=''>vector</span> <span style=''>machine</span> <span style=''>(RVM)</span> <span style=''>are</span> <span style=''>not</span> <span style=''>capable</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eliminating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>irrelevant</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4054054054054053);'>redundant</span> <span style=''>features</span> <span style=''>which</span> <span style=''>could</span> <span style=''>lead</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.6363636363636362);'>degradation</span> <span style=''>To</span> <span style=''>tackle</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>sparse</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simultaneously</span> <span style=''>selects</span> <span style=''>the</span> <span style=''>relevant</span> <span style=''>samples</span> <span style=''>and</span> <span style=''>features</span> <span style=''>We</span> <span style=''>name</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>vector</span> <span style=''>machine</span> <span style=''>(PFCVM)</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.30434782608695665);'>truncated</span> <span style=''>Gaussian</span> <span style='background-color:rgba(255, 0, 0, 0.3453453453453453);'>distributions</span> <span style=''>are</span> <span style=''>em</span> <span style=''>ployed</span> <span style=''>as</span> <span style=''>both</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>State</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>State</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(PSRNNs)</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>PSRNNs</span> <span style=''>draw</span> <span style=''>on</span> <span style=''>insights</span> <span style=''>from</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Recurrent</span> <span style=''>Neural</span> <span style=''>Networks</span> <span style=''>(RNNs)</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Predictive</span> <span style=''>State</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Representations</span> <span style=''>(PSRs)</span> <span style=''>and</span> <span style=''>inherit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>advantages</span> <span style=''>from</span> <span style=''>both</span> <span style=''>types</span> <span style=''>of</span> <span style=''>models</span> <span style=''>Like</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>successful</span> <span style=''>RNN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>PSRNNs</span> <span style=''>use</span> <span style=''>(potentially</span> <span style=''>deeply</span> <span style=''>composed)</span> <span style=''>bilinear</span> <span style=''>transfer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>to</span> <span style=''>combine</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>from</span> <span style=''>multiple</span> <span style=''>sources</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>such</span> <span style=''>bilinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>arise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>naturally</span> <span style=''>from</span> <span style=''>state</span> <span style=''>updates</span> <span style=''>in</span> <span style=''>Bayes</span> <span style=''>filters</span> <span style=''>like</span> <span style=''>PSRs</span> <span style=''>in</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observations</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>gating</span> <span style=''>belief</span> <span style=''>states</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>PSRNNs</span> <span style=''>can</span> <span style=''>be</span> <span style=''>learned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effectively</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>Backpropogation</span> <span style=''>Through</span> <span style=''>Time</span> <span style=''>(BPTT)</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>derived</span>  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13597430406852248)
# 	representation (0.13561741613133477)
# 	knowledge (0.11955745895788722)
# 	architecture (0.08886509635974305)
# 	segmentation (0.0681655960028551)
# 	information (0.251249107780157)
# 	different (0.26088508208422556)
# 	detection (0.11848679514632406)
# 	recognition (0.13133476088508209)
# 	convolutional (0.12883654532476801)
#
# Some Statistics words are:
# 	stochastic (0.13913913913913914)
# 	estimation (0.16616616616616617)
# 	variables (0.14064064064064064)
# 	statistical (0.16216216216216217)
# 	algorithm (0.3963963963963964)
# 	theoretical (0.16116116116116116)
# 	distribution (0.18868868868868868)
# 	inference (0.19119119119119118)
# 	dimensional (0.1816816816816817)
# 	regression (0.17917917917917917)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3421e363-f220-4744-8609-db8643346400" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3421e363-f220-4744-8609-db8643346400")) {                    Plotly.newPlot(                        "3421e363-f220-4744-8609-db8643346400",                        [{"x":["technically","clustered","classification","extraction","interface","geographical","information","retrieved","visualization","similarity","meaningful","retrieval","processing","clustering","efficient","inference","automatically","including","functions","searching","structured","importantly","applicable","intractable","probability","competitive","introduce","ambiguities","prediction","structures","dependency","implausible","regardless","assignment","attractive","structure","differentiable","experiments","corresponding","combinatorial","backpropagation","interpretability","parameter","synthetic","independent","separation","exploitation","algorithm","assumption","application","performance","minimization","restrictive","additionally","incorporated","component","diversity","applications","statistically","enhancing","independence","statistical","important","improvement","available","resulting","resonance","exploiting","functional","simulations","perturbed","perturbations","dictionary","indicating","evaluated","representing","reconstruction","protection","complexity","misclassified","architectures","effective","confidence","adversarial","architecture","previously","progression","technique","successive","techniques","representations","perturbation","denoising","different","implement","panoramic","transform","gradients","representative","artificial","histogram","invariant","convolutional","algorithms","cognition","radiographs","intelligence","technology","unscented","traditional","derivation","parameters","management","complicated","nonlinear","attention","perception","described","environment","potential","estimation","mechanism","calculations","comparison","cognitive","evaluation","simulation","computation","computing","implemented","technical","presumably","programming","probabilistic","describes","deconvolution","iterations","literature","variables","theoretical","dimensional","mentioned","procedure","community","validated","counterpart","silhouettes","boltzmann","observations","surprising","regarding","efficiency","distributed","expectation","representational","demonstrate","inefficient","binarized","generative","alternative","approximate","efficiently","advantages","representation","outperform","restricted","empirical","evidences","generation","captioning","decomposition","computational","challenging","convergence","recognition","outperforms","expensive","approximations","specifically","recurrent","approximation","predicting","correlation","transactions","regression","predictions","therefore","correlations","adjacency","operators","overcomes","heterogeneous","respectively","transportation","examination","schedules","generalization","supervised","dimension","implementation","optimization","transport","uncertainty","distribution","discussion","stochastic","unlabeled","distributionally","formulation","estimators","proposing","procedures","reduction","distributions","gaussianity","continuous","identifiable","relations","excellent","statistics","discovering","exclusive","experimental","bernoulli","governing","preferred","compiling","uniformly","transformed","translation","correspond","preferences","dedicated","describing","respected","interested","incorporating","preference","implementations","orderings","methodology","specification","semantics","developed","evaluations","transformations","otherwise","significantly","projections","transformation","asymmetric","sensitive","chal ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	radiographs
# 	disconnected
# 	katehakis
# 	inductively
# 	methodologically
# 	ultrahigh
# 	ellipsoids
# 	nesterovs
# 	overparameterized
# 	contributors
# 	penalizations
# 	nonlinearly
# 	amortization
# 	uncontaminated
# 	varepsilon
# 	calculable
# 	lindenstrauss
# 	prognostics
# 	recoverability
# 	robustifying
# Some words which never appear in Statistics papers:
# 	evidences
# 	compiling
# 	orderings
# 	subdivide
# 	delineate
# 	recognising
# 	photographs
# 	delineation
# 	compilation
# 	discourse
# 	experimented
# 	acknowledge
# 	bilingual
# 	morphologically
# 	organizational
# 	multiphase
# 	textureless
# 	untextured
# 	conversions
# 	incapability

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.071347400104426e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
